# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


heart = pd.read_csv('heart.csv')

# %% [markdown]
# # Exploring data

# %%
heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
heart['Sex']=heart['Sex'].map({"M":1,"F":0})

# %%
heart.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
# 2   37    1           ATA        130          283          0         ST
# 3   48    0           ASY        138          214          0     Normal
# 4   54    1           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
df_heart = heart.copy()
df_heart.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
# 2   37    1           ATA        130          283          0         ST
# 3   48    0           ASY        138          214          0     Normal
# 4   54    1           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
df_heart =  pd.get_dummies(df_heart,columns= ['ChestPainType'],drop_first=False)
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40    1        140          289          0     Normal    172
# 1   49    0        160          180          0     Normal    156
# 2   37    1        130          283          0         ST     98
# 3   48    0        138          214          0     Normal    108
# 4   54    1        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  ChestPainType_ASY  \
# 0              N      0.0       Up             0              False
# 1              N      1.0     Flat             1              False
# 2              N      0.0       Up             0              False
# 3              Y      1.5     Flat             1               True
# 4              N      0.0       Up             0              False
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA
# 0               True              False             False
# 1              False               True             False
# 2               True              False             False
# 3              False              False             False
# 4              False               True             False

# %%
df_heart =  pd.get_dummies(df_heart,columns= ['RestingECG'],drop_first=False)

# %%
df_heart['ExerciseAngina'] = df_heart['ExerciseAngina'].map({"Y":1, "N":0})

# %%
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172               0
# 1   49    0        160          180          0    156               0
# 2   37    1        130          283          0     98               0
# 3   48    0        138          214          0    108               1
# 4   54    1        150          195          0    122               0
#
#    Oldpeak  HeartDisease  ChestPainType_ASY  ChestPainType_ATA  \
# 0      0.0             0                  0                  1
# 1      1.0             1                  0                  0
# 2      0.0             0                  0                  1
# 3      1.5             1                  1                  0
# 4      0.0             0                  0                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0                  0                 0               0                  1
# 1                  1                 0               0                  1
# 2                  0                 0               0                  0
# 3                  0                 0               0                  1
# 4                  1                 0               0                  1
#
#    RestingECG_ST  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              0              0            1
# 1              0              0              1            0
# 2              1              0              0            1
# 3              0              0              1            0
# 4              0              0              0            1

# %%
print(df_heart.columns.tolist())
# Out:
# ['Age', 'Sex', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST']

# %%
df_heart.dtypes
# Out:
# Age                    int64
# Sex                    int64
# RestingBP              int64
# Cholesterol            int64
# FastingBS              int64
# MaxHR                  int64
# ExerciseAngina         int64
# Oldpeak              float64
# ST_Slope              object
# HeartDisease           int64
# ChestPainType_ASY       bool
# ChestPainType_ATA       bool
# ChestPainType_NAP       bool
# ChestPainType_TA        bool
# RestingECG_LVH          bool
# RestingECG_Normal       bool
# RestingECG_ST           bool
# dtype: object

# %%
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172               0
# 1   49    0        160          180          0    156               0
# 2   37    1        130          283          0     98               0
# 3   48    0        138          214          0    108               1
# 4   54    1        150          195          0    122               0
#
#    Oldpeak ST_Slope  HeartDisease  ChestPainType_ASY  ChestPainType_ATA  \
# 0      0.0       Up             0              False               True
# 1      1.0     Flat             1              False              False
# 2      0.0       Up             0              False               True
# 3      1.5     Flat             1               True              False
# 4      0.0       Up             0              False              False
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0              False             False           False               True
# 1               True             False           False               True
# 2              False             False           False              False
# 3              False             False           False               True
# 4               True             False           False               True
#
#    RestingECG_ST
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False

# %%
bool_col = df_heart.select_dtypes(include='bool').columns
df_heart[bool_col] = df_heart[bool_col].astype(int)

# %%
df_heart['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
njdf_heart = pd.get_dummies(df_heart,columns =['ST_Slope'], drop_first = False)

# %%
bol_col = df_heart.select_dtypes(include='bool').columns
df_heart[bol_col] = df_heart[bol_col].astype(int)

# %%
df_heart.value_counts().sum()
# Out:
# np.int64(0)

# %%
df_heart['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
for col in df_heart.columns:
    null_count = df_heart[col].isna().sum()
    if null_count>0:
        print(col,null_count)
# Out:
# ExerciseAngina 918

# %%
df_heart.shape
# Out:
# (918, 19)

# %%
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172               0
# 1   49    0        160          180          0    156               0
# 2   37    1        130          283          0     98               0
# 3   48    0        138          214          0    108               1
# 4   54    1        150          195          0    122               0
#
#    Oldpeak  HeartDisease  ChestPainType_ASY  ChestPainType_ATA  \
# 0      0.0             0                  0                  1
# 1      1.0             1                  0                  0
# 2      0.0             0                  0                  1
# 3      1.5             1                  1                  0
# 4      0.0             0                  0                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0                  0                 0               0                  1
# 1                  1                 0               0                  1
# 2                  0                 0               0                  0
# 3                  0                 0               0                  1
# 4                  1                 0               0                  1
#
#    RestingECG_ST  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0              0              0              0            1
# 1              0              0              1            0
# 2              1              0              0            1
# 3              0              0              1            0
# 4              0              0              0            1

# %% [markdown]
# generating all the models at once namely
# **bold text**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = df_heart.drop('HeartDisease',axis = 1)
y = df_heart['HeartDisease']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(),
    'SVM': SVC(),
    'KNN': KNeighborsClassifier()
}
result = []

# %%
for x in models:
  model =models[x]
  model.fit(X_train_scaled,y_train)
  y_pred = model.predict(X_test_scaled)
  accur = accuracy_score(y_test,y_pred)
  f1 = f1_score(y_test,y_pred)
  result.append(
      {
          'model': x,
          'accuracy':round(accur,4),
          'f1_score':round(f1,4)
      }
  )

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'accuracy': 0.8587, 'f1_score': 0.875},
#  {'model': 'Naive Bayes', 'accuracy': 0.8587, 'f1_score': 0.875},
#  {'model': 'Decision Tree', 'accuracy': 0.8207, 'f1_score': 0.8406},
#  {'model': 'SVM', 'accuracy': 0.8859, 'f1_score': 0.9014},
#  {'model': 'KNN', 'accuracy': 0.8641, 'f1_score': 0.8792}]

# %%
import joblib

joblib.dump(models['KNN'], 'KNN_heart.pkl')   # Saves the trained KNN model
joblib.dump(scaler, 'scaler.pkl')             # Saves the fitted scaler (used for preprocessing)
# Out:
# ['scaler.pkl']
