# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


heart = pd.read_csv('heart.csv')

# %% [markdown]
# # Exploring data

# %%
heart.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
heart['Sex']=heart['Sex'].map({"M":1,"F":0})

# %%
heart.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
# 2   37    1           ATA        130          283          0         ST
# 3   48    0           ASY        138          214          0     Normal
# 4   54    1           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
df_heart = heart.copy()
df_heart.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    1           ATA        140          289          0     Normal
# 1   49    0           NAP        160          180          0     Normal
# 2   37    1           ATA        130          283          0         ST
# 3   48    0           ASY        138          214          0     Normal
# 4   54    1           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
df_heart =  pd.get_dummies(df_heart,columns= ['ChestPainType'],drop_first=False)
df_heart.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1979/642651740.py in <cell line: 0>()
# ----> 1 df_heart =  pd.get_dummies(df_heart,columns= ['ChestPainType'],drop_first=False)
#       2 df_heart.head()
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
df_heart =  pd.get_dummies(df_heart,columns= ['RestingECG'],drop_first=False)
df_heart.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1979/1136707910.py in <cell line: 0>()
# ----> 1 df_heart =  pd.get_dummies(df_heart,columns= ['RestingECG'],drop_first=False)
#       2 df_heart.head()
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# ...

# %%
df_heart['ExerciseAngina'] = df_heart['ExerciseAngina'].map({"Y":1, "N":0})

# %%
print(df_heart.columns.tolist())
# Out:
# ['Age', 'Sex', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'HeartDisease', 'ChestPainType_ASY', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA', 'RestingECG_LVH', 'RestingECG_Normal', 'RestingECG_ST', 'ST_Slope_Down', 'ST_Slope_Flat', 'ST_Slope_Up']

# %%
type(df_heart)
# Out:
# pandas.core.frame.DataFrame

# %%
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172             NaN
# 1   49    0        160          180          0    156             NaN
# 2   37    1        130          283          0     98             NaN
# 3   48    0        138          214          0    108             NaN
# 4   54    1        150          195          0    122             NaN
#
#    Oldpeak  HeartDisease  ChestPainType_ASY  ChestPainType_ATA  \
# 0      0.0             0                  0                  1
# 1      1.0             1                  0                  0
# 2      0.0             0                  0                  1
# 3      1.5             1                  1                  0
# 4      0.0             0                  0                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0                  0                 0               0                  1
# ...

# %%
bool_col = df_heart.select_dtypes(include='bool').columns
df_heart[bool_col] = df_heart[bool_col].astype(int)

# %%
df_heart['ST_Slope'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ST_Slope'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1979/1524372284.py in <cell line: 0>()
# ----> 1 df_heart['ST_Slope'].unique()
#
# ...

# %%
df_heart.dtypes
# Out:
# Age                    int64
# Sex                    int64
# RestingBP              int64
# Cholesterol            int64
# FastingBS              int64
# MaxHR                  int64
# ExerciseAngina       float64
# Oldpeak              float64
# HeartDisease           int64
# ChestPainType_ASY      int64
# ChestPainType_ATA      int64
# ChestPainType_NAP      int64
# ChestPainType_TA       int64
# RestingECG_LVH         int64
# RestingECG_Normal      int64
# RestingECG_ST          int64
# ST_Slope_Down          int64
# ST_Slope_Flat          int64
# ST_Slope_Up            int64
# dtype: object

# %%
df_heart = pd.get_dummies(df_heart,columns =['ST_Slope'], drop_first = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1979/4290282540.py in <cell line: 0>()
# ----> 1 df_heart = pd.get_dummies(df_heart,columns =['ST_Slope'], drop_first = False)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
# ...

# %%
bol_col = df_heart.select_dtypes(include='bool').columns
df_heart[bol_col] = df_heart[bol_col].astype(int)

# %%
df_heart.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    1        140          289          0    172             NaN
# 1   49    0        160          180          0    156             NaN
# 2   37    1        130          283          0     98             NaN
# 3   48    0        138          214          0    108             NaN
# 4   54    1        150          195          0    122             NaN
#
#    Oldpeak  HeartDisease  ChestPainType_ASY  ChestPainType_ATA  \
# 0      0.0             0                  0                  1
# 1      1.0             1                  0                  0
# 2      0.0             0                  0                  1
# 3      1.5             1                  1                  0
# 4      0.0             0                  0                  0
#
#    ChestPainType_NAP  ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  \
# 0                  0                 0               0                  1
# ...

# %%
df_heart.dtypes
# Out:
# Age                    int64
# Sex                    int64
# RestingBP              int64
# Cholesterol            int64
# FastingBS              int64
# MaxHR                  int64
# ExerciseAngina       float64
# Oldpeak              float64
# HeartDisease           int64
# ChestPainType_ASY      int64
# ChestPainType_ATA      int64
# ChestPainType_NAP      int64
# ChestPainType_TA       int64
# RestingECG_LVH         int64
# RestingECG_Normal      int64
# RestingECG_ST          int64
# ST_Slope_Down          int64
# ST_Slope_Flat          int64
# ST_Slope_Up            int64
# dtype: object

# %%
df_heart.value_counts().sum()
# Out:
# np.int64(0)

# %%
df_heart['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
for col in df_heart.columns:
    null_count = df_heart[col].isna().sum()
    if null_count>0:
        print(col,null_count)
# Out:
# ExerciseAngina 918

# %%
df_heart.shape
# Out:
# (918, 19)
